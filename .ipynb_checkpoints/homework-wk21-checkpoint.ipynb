# %% [markdown]
# # Q. 1.
# Create a basic API in Azure (as we did in class) that tells you how to access the different endpoints when you go to the home page. You should have the following endpoints:
#
#     A /all endpoint that displays all of the nobel.json data
#
#     B /<year> GET endpoint that allows for you to pass in any year and shows you the Nobel prizes from that year. No need to create an HTML page for this, but you can if you want.
#
#     C /add POST endpoint that lets you add additional data
#
#     You should use a basic HTML form, but you can also pass the data into the API url if you’re feeling ambitious. The latter may require use of a tool called Postman. First, make sure the data from the form is getting passed to python, and then work on appending it to the json file.
#
#     Make sure you see your updates when you go to /all

# %% [markdown]
# A. *For this part started the same way as the one in class, added the nobel data to the static folder, and ran the flask app in my virtual environment*

# %% [markdown]
# ![flask-all.jpg](attachment:flask-all.jpg)

# %% [markdown]
# B. *Going through Alexis' code that was in the extra reading, added both a get and post method in my code. Also added the form.html that she had mentioned in her code to add*

# %% [markdown]
# ![flask-year.jpg](attachment:flask-year.jpg)

# %% [markdown]
# C. *changed the form.html and added the new dictionary in the .py file to be able to add information*

# %% [markdown]
# ![flask-add.png](attachment:flask-add.png)

# %% [markdown]
# ![flask1.png](attachment:flask1.png)

# %% [markdown]
# ![flask2.png](attachment:flask2.png)

# %% [markdown]
# # Q. 2.
#  What kind of API did you build? What types of APIs are there? Why are APIs important?

# %% [markdown]
# There are four principal types of API commonly used in web-based applications: public, partner, private and composite. Ours was a private one because it was only on a local server.
#
#
# APIs are important because they can be a service for developers. Every time developers write a new program, they don’t have to start from scratch to build a core application that tries to do everything. Instead, they can contract out certain responsibilities by using already created pieces that do the job better. APIs let you interact with applications. It is a set of functions that allows applications to access data and interact with external software components, operating systems, or microservices. To simplify, an API delivers a user response to a system and sends the system's response back to a user.

# %% [markdown]
# ![cloudcomputing.jpg](attachment:cloudcomputing.jpg)
